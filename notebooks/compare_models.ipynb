# %%
from pycaret.classification import setup, compare_models, evaluate_model
import pandas as pd

# %%
# load treated data set
train_set = pd.read_parquet('../data/05_model_input/train_dataset_kobe_dev.parquet')
test_set = pd.read_parquet('../data/05_model_input/test_dataset_kobe_dev.parquet')
train_set.head()
# Out:
#            lat       lon  minutes_remaining  period  playoffs  shot_distance  \
# 26131  33.8633 -118.2818                  8       3         0             18
# 16057  34.0443 -118.2698                  9       3         0              0
# 1103   34.0443 -118.2698                  6       3         0              0
# 26435  34.0443 -118.2698                  5       2         1              0
# 21046  34.0433 -118.2748                  3       1         0              0
#
#        shot_made_flag
# 26131             1.0
# 16057             1.0
# 1103              0.0
# 26435             1.0
# 21046             1.0

# %%
# check if it has null values
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16228 entries, 26131 to 14158
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   lat                16228 non-null  float64
#  1   lon                16228 non-null  float64
#  2   minutes_remaining  16228 non-null  int64
#  3   period             16228 non-null  int64
#  4   playoffs           16228 non-null  int64
#  5   shot_distance      16228 non-null  int64
#  6   shot_made_flag     16228 non-null  float64
# dtypes: float64(3), int64(4)
# memory usage: 1014.2 KB

# %%
# check basis statistics
train_set.describe()
# Out:
#                 lat           lon  minutes_remaining        period  \
# count  16228.000000  16228.000000       16228.000000  16228.000000
# mean      33.980860   -118.262196           5.100136      2.475228
# std        0.065865      0.093494           3.422079      1.149379
# min       33.809300   -118.487800           0.000000      1.000000
# 25%       33.926300   -118.313800           2.000000      1.000000
# 50%       33.999800   -118.269800           5.000000      3.000000
# 75%       34.044300   -118.194800           8.000000      3.000000
# max       34.088300   -118.049800          11.000000      7.000000
#
#            playoffs  shot_distance  shot_made_flag
# count  16228.000000   16228.000000    16228.000000
# mean       0.149864      10.214013        0.477323
# std        0.356949       7.554856        0.499501
# min        0.000000       0.000000        0.000000
# 25%        0.000000       1.000000        0.000000
# 50%        0.000000      12.000000        0.000000
# 75%        0.000000      17.000000        1.000000
# max        1.000000      26.000000        1.000000

# %%
target_column = 'shot_made_flag'
s = setup(train_set, target = target_column, session_id=123, fix_imbalance=True)
# Out:
# <style type="text/css">
# #T_2d579_row8_col1, #T_2d579_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2d579">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2d579_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_2d579_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d579_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2d579_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_2d579_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_2d579_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2d579_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2d579_row1_col1" class="data row1 col1" >shot_made_flag</td>
#     </tr>
#     <tr>
#       <th id="T_2d579_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2d579_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_2d579_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_2d579_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2d579_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_2d579_row3_col1" class="data row3 col1" >(16228, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_2d579_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2d579_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_2d579_row4_col1" class="data row4 col1" >(16743, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_2d579_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2d579_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_2d579_row5_col1" class="data row5 col1" >(11874, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_2d579_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2d579_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_2d579_row6_col1" class="data row6 col1" >(4869, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_2d579_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2d579_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_2d579_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_2d579_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2d579_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_2d579_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2d579_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2d579_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_2d579_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_2d579_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2d579_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_2d579_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_2d579_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2d579_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_2d579_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_2d579_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2d579_row12_col0" class="data row12 col0" >Fix imbalance</td>
#       <td id="T_2d579_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2d579_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2d579_row13_col0" class="data row13 col0" >Fix imbalance method</td>
#       <td id="T_2d579_row13_col1" class="data row13 col1" >SMOTE</td>
#     </tr>
#     <tr>
#       <th id="T_2d579_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2d579_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_2d579_row14_col1" class="data row14 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_2d579_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_2d579_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_2d579_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_2d579_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_2d579_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_2d579_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_2d579_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_2d579_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_2d579_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2d579_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_2d579_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_2d579_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2d579_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_2d579_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_2d579_row19_col1" class="data row19 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_2d579_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_2d579_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_2d579_row20_col1" class="data row20 col1" >dd01</td>
#     </tr>
#   </tbody>
# </table>

# %%
# check inbalance 
train_set[target_column].value_counts()
# Out:
# shot_made_flag
# 0.0    8482
# 1.0    7746
# Name: count, dtype: int64

# %%
best = compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              19:54:38
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# #T_ebfa6 th {
#   text-align: left;
# }
# #T_ebfa6_row0_col0, #T_ebfa6_row0_col2, #T_ebfa6_row0_col3, #T_ebfa6_row0_col5, #T_ebfa6_row1_col0, #T_ebfa6_row1_col1, #T_ebfa6_row1_col2, #T_ebfa6_row1_col3, #T_ebfa6_row1_col4, #T_ebfa6_row1_col5, #T_ebfa6_row1_col7, #T_ebfa6_row2_col0, #T_ebfa6_row2_col1, #T_ebfa6_row2_col2, #T_ebfa6_row2_col3, #T_ebfa6_row2_col4, #T_ebfa6_row2_col5, #T_ebfa6_row2_col6, #T_ebfa6_row2_col7, #T_ebfa6_row3_col0, #T_ebfa6_row3_col1, #T_ebfa6_row3_col2, #T_ebfa6_row3_col3, #T_ebfa6_row3_col4, #T_ebfa6_row3_col5, #T_ebfa6_row3_col6, #T_ebfa6_row3_col7, #T_ebfa6_row4_col0, #T_ebfa6_row4_col1, #T_ebfa6_row4_col2, #T_ebfa6_row4_col3, #T_ebfa6_row4_col4, #T_ebfa6_row4_col5, #T_ebfa6_row4_col6, #T_ebfa6_row4_col7, #T_ebfa6_row5_col0, #T_ebfa6_row5_col1, #T_ebfa6_row5_col2, #T_ebfa6_row5_col3, #T_ebfa6_row5_col4, #T_ebfa6_row5_col5, #T_ebfa6_row5_col6, #T_ebfa6_row5_col7, #T_ebfa6_row6_col0, #T_ebfa6_row6_col1, #T_ebfa6_row6_col3, #T_ebfa6_row6_col4, #T_ebfa6_row6_col6, #T_ebfa6_row6_col7, #T_ebfa6_row7_col0, #T_ebfa6_row7_col1, #T_ebfa6_row7_col2, #T_ebfa6_row7_col3, #T_ebfa6_row7_col4, #T_ebfa6_row7_col5, #T_ebfa6_row7_col6, #T_ebfa6_row7_col7, #T_ebfa6_row8_col0, #T_ebfa6_row8_col1, #T_ebfa6_row8_col2, #T_ebfa6_row8_col3, #T_ebfa6_row8_col4, #T_ebfa6_row8_col5, #T_ebfa6_row8_col6, #T_ebfa6_row8_col7, #T_ebfa6_row9_col0, #T_ebfa6_row9_col1, #T_ebfa6_row9_col2, #T_ebfa6_row9_col3, #T_ebfa6_row9_col4, #T_ebfa6_row9_col5, #T_ebfa6_row9_col6, #T_ebfa6_row9_col7, #T_ebfa6_row10_col0, #T_ebfa6_row10_col1, #T_ebfa6_row10_col2, #T_ebfa6_row10_col4, #T_ebfa6_row10_col5, #T_ebfa6_row10_col6, #T_ebfa6_row10_col7, #T_ebfa6_row11_col0, #T_ebfa6_row11_col1, #T_ebfa6_row11_col2, #T_ebfa6_row11_col3, #T_ebfa6_row11_col4, #T_ebfa6_row11_col5, #T_ebfa6_row11_col6, #T_ebfa6_row11_col7, #T_ebfa6_row12_col0, #T_ebfa6_row12_col1, #T_ebfa6_row12_col2, #T_ebfa6_row12_col3, #T_ebfa6_row12_col4, #T_ebfa6_row12_col5, #T_ebfa6_row12_col6, #T_ebfa6_row12_col7, #T_ebfa6_row13_col0, #T_ebfa6_row13_col1, #T_ebfa6_row13_col2, #T_ebfa6_row13_col3, #T_ebfa6_row13_col4, #T_ebfa6_row13_col5, #T_ebfa6_row13_col6, #T_ebfa6_row13_col7 {
#   text-align: left;
# }
# #T_ebfa6_row0_col1, #T_ebfa6_row0_col4, #T_ebfa6_row0_col6, #T_ebfa6_row0_col7, #T_ebfa6_row1_col6, #T_ebfa6_row6_col2, #T_ebfa6_row6_col5, #T_ebfa6_row10_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ebfa6_row0_col8, #T_ebfa6_row1_col8, #T_ebfa6_row2_col8, #T_ebfa6_row3_col8, #T_ebfa6_row4_col8, #T_ebfa6_row5_col8, #T_ebfa6_row6_col8, #T_ebfa6_row7_col8, #T_ebfa6_row8_col8, #T_ebfa6_row9_col8, #T_ebfa6_row10_col8, #T_ebfa6_row11_col8, #T_ebfa6_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ebfa6_row12_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ebfa6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ebfa6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ebfa6_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ebfa6_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ebfa6_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ebfa6_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ebfa6_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ebfa6_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ebfa6_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_ebfa6_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ebfa6_level0_row0" class="row_heading level0 row0" >gbc</th>
#       <td id="T_ebfa6_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_ebfa6_row0_col1" class="data row0 col1" >0.5861</td>
#       <td id="T_ebfa6_row0_col2" class="data row0 col2" >0.5977</td>
#       <td id="T_ebfa6_row0_col3" class="data row0 col3" >0.4170</td>
#       <td id="T_ebfa6_row0_col4" class="data row0 col4" >0.5951</td>
#       <td id="T_ebfa6_row0_col5" class="data row0 col5" >0.4901</td>
#       <td id="T_ebfa6_row0_col6" class="data row0 col6" >0.1597</td>
#       <td id="T_ebfa6_row0_col7" class="data row0 col7" >0.1670</td>
#       <td id="T_ebfa6_row0_col8" class="data row0 col8" >0.4270</td>
#     </tr>
#     <tr>
#       <th id="T_ebfa6_level0_row1" class="row_heading level0 row1" >ada</th>
#       <td id="T_ebfa6_row1_col0" class="data row1 col0" >Ada Boost Classifier</td>
#       <td id="T_ebfa6_row1_col1" class="data row1 col1" >0.5855</td>
#       <td id="T_ebfa6_row1_col2" class="data row1 col2" >0.5965</td>
#       <td id="T_ebfa6_row1_col3" class="data row1 col3" >0.4340</td>
#       <td id="T_ebfa6_row1_col4" class="data row1 col4" >0.5897</td>
#       <td id="T_ebfa6_row1_col5" class="data row1 col5" >0.4995</td>
#       <td id="T_ebfa6_row1_col6" class="data row1 col6" >0.1597</td>
#       <td id="T_ebfa6_row1_col7" class="data row1 col7" >0.1654</td>
#       <td id="T_ebfa6_row1_col8" class="data row1 col8" >0.1350</td>
#     </tr>
#     <tr>
#       <th id="T_ebfa6_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_ebfa6_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_ebfa6_row2_col1" class="data row2 col1" >0.5735</td>
#       <td id="T_ebfa6_row2_col2" class="data row2 col2" >0.5957</td>
#       <td id="T_ebfa6_row2_col3" class="data row2 col3" >0.5367</td>
#       <td id="T_ebfa6_row2_col4" class="data row2 col4" >0.5554</td>
#       <td id="T_ebfa6_row2_col5" class="data row2 col5" >0.5458</td>
#       <td id="T_ebfa6_row2_col6" class="data row2 col6" >0.1440</td>
#       <td id="T_ebfa6_row2_col7" class="data row2 col7" >0.1441</td>
#       <td id="T_ebfa6_row2_col8" class="data row2 col8" >0.4800</td>
#     </tr>
#     <tr>
#       <th id="T_ebfa6_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_ebfa6_row3_col0" class="data row3 col0" >Ridge Classifier</td>
#       <td id="T_ebfa6_row3_col1" class="data row3 col1" >0.5728</td>
#       <td id="T_ebfa6_row3_col2" class="data row3 col2" >0.5979</td>
#       <td id="T_ebfa6_row3_col3" class="data row3 col3" >0.5389</td>
#       <td id="T_ebfa6_row3_col4" class="data row3 col4" >0.5543</td>
#       <td id="T_ebfa6_row3_col5" class="data row3 col5" >0.5463</td>
#       <td id="T_ebfa6_row3_col6" class="data row3 col6" >0.1428</td>
#       <td id="T_ebfa6_row3_col7" class="data row3 col7" >0.1429</td>
#       <td id="T_ebfa6_row3_col8" class="data row3 col8" >0.0240</td>
#     </tr>
#     <tr>
#       <th id="T_ebfa6_level0_row4" class="row_heading level0 row4" >lda</th>
#       <td id="T_ebfa6_row4_col0" class="data row4 col0" >Linear Discriminant Analysis</td>
#       <td id="T_ebfa6_row4_col1" class="data row4 col1" >0.5728</td>
#       <td id="T_ebfa6_row4_col2" class="data row4 col2" >0.5978</td>
#       <td id="T_ebfa6_row4_col3" class="data row4 col3" >0.5391</td>
#       <td id="T_ebfa6_row4_col4" class="data row4 col4" >0.5543</td>
#       <td id="T_ebfa6_row4_col5" class="data row4 col5" >0.5464</td>
#       <td id="T_ebfa6_row4_col6" class="data row4 col6" >0.1428</td>
#       <td id="T_ebfa6_row4_col7" class="data row4 col7" >0.1429</td>
#       <td id="T_ebfa6_row4_col8" class="data row4 col8" >0.0200</td>
#     </tr>
#     <tr>
#       <th id="T_ebfa6_level0_row5" class="row_heading level0 row5" >nb</th>
#       <td id="T_ebfa6_row5_col0" class="data row5 col0" >Naive Bayes</td>
#       <td id="T_ebfa6_row5_col1" class="data row5 col1" >0.5709</td>
#       <td id="T_ebfa6_row5_col2" class="data row5 col2" >0.5927</td>
#       <td id="T_ebfa6_row5_col3" class="data row5 col3" >0.5231</td>
#       <td id="T_ebfa6_row5_col4" class="data row5 col4" >0.5537</td>
#       <td id="T_ebfa6_row5_col5" class="data row5 col5" >0.5378</td>
#       <td id="T_ebfa6_row5_col6" class="data row5 col6" >0.1380</td>
#       <td id="T_ebfa6_row5_col7" class="data row5 col7" >0.1383</td>
#       <td id="T_ebfa6_row5_col

# %%
# See performance of the model
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
